# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
haberman = pd.read_csv('Datasets/haberman.csv')

# %%
haberman
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# 5    33  60   0    1
# 6    34  59   0    2
# 7    34  66   9    2
# 8    34  58  30    1
# 9    34  60   1    1
# 10   34  61  10    1
# 11   34  67   7    1
# 12   34  60   0    1
# 13   35  64  13    1
# 14   35  63   0    1
# 15   36  60   1    1
# 16   36  69   0    1
# 17   37  60   0    1
# 18   37  63   0    1
# 19   37  58   0    1
# 20   37  59   6    1
# 21   37  60  15    1
# 22   37  63   0    1
# 23   38  69  21    2
# 24   38  59   2    1
# 25   38  60   0    1
# 26   38  60   0    1
# 27   38  62   3    1
# 28   38  64   1    1
# 29   38  66   0    1
# ..   ..  ..  ..  ...
# 275  67  66   0    1
# 276  67  61   0    1
# 277  67  65   0    1
# 278  68  67   0    1
# 279  68  68   0    1
# 280  69  67   8    2
# 281  69  60   0    1
# 282  69  65   0    1
# 283  69  66   0    1
# 284  70  58   0    2
# 285  70  58   4    2
# ...

# %%
print(haberman.shape)
# Out:
# (305, 4)

# %%
print(haberman.columns)
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
haberman['1.1'].value_counts()
# Out:
# 1    224
# 2     81
# Name: 1.1, dtype: int64

# %% [markdown]
# ####  224 people out of 305 survived longer than 5 years after their operation and rest of them died within 5 years

# %% [markdown]
# ## 2D Scatter Plots

# %%
haberman.plot(kind='scatter',x='30',y='64')
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(haberman,hue='1.1',size=4).map(plt.scatter,'30','64').add_legend()
# Out:
# c:\python\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 3D Scatter Plot

# %%
sns.pairplot(haberman,hue='1.1',size=3)
plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
haberman_survive = haberman.loc[haberman['1.1'] == 1]
haberman_not = haberman.loc[haberman['1.1'] == 2]

# %%
plt.plot(haberman_survive['30'],np.zeros_like(haberman_survive['30']))

# %%
sns.FacetGrid(haberman , hue = '1.1', size = 5).map(sns.distplot , '30').add_legend()
# Out:
# c:\python\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(haberman , hue = '1.1', size = 5).map(sns.distplot , '64').add_legend()
# Out:
# c:\python\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(haberman , hue = '1.1', size = 5).map(sns.distplot , '1').add_legend()
# Out:
# c:\python\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='1.1',y='1',data=haberman)

# %%
sns.boxplot(x='1.1',y='30',data=haberman)

# %%
sns.boxplot(x='1.1',y='64',data=haberman)

# %%
sns.jointplot(x='1',y='64',data=haberman_survive,kind='kde')
